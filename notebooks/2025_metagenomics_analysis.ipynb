# %% [markdown]
# # purpose
# to take the varied outputs from obitools and blast and make plots for papers. Probably this should end up being a set of functions that can be called from a script, but for now I'm just exploring the data and thinking about how to properly plot it

# %% [raw]
# ## thoughts
# - info files
# - filter out bad quality
# - add number of reads
#
# Turtle paper:
#     e-20 cutoff
#     5 most significant with >97.6 identity
#     if agree, mark as taxon, if different species, mark as genus, if not local, mark as genus
#
# obi notes:
#     import sanger makes 2016/read_j_F/R
#     ecotag 0.97 makes 2016/result_j_F/R
#     export makes exp5_out/...csv
# then blastitall
#     if there's a >96% match, combine sequences into one result
#     if there are more than 15 of those 96% identity sequences, it makes the cut
#     currently, it also requires that the median score is at least 32
#     for each sequence, it makes a file results_j_seqnum.csv and xml of total BLAST results
#     currently uses if hsp.expect < 1e-20, was 1e-10
#     currently makes an info file, these were remade for all the old sequences

# %% [markdown]
# # imports

# %%
import numpy as np
import pandas as pd
import os, math, sys
import matplotlib.pyplot as plt

# %% [markdown]
# # functions

# %% [markdown]
# # procedure
