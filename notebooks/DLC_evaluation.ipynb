# %% [markdown]
# # Purpose
# to help us figure out how consistently our labels are across humans

# %% [markdown]
# # Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os, sys, glob, math
import itertools

# %% [markdown]
# # Functions

# %%
def load_and_reformat(location):
    df = pd.read_csv(location,header=[0,1,2,3],index_col=[0,1,2])
    new_df=df.melt(value_vars=list(df.columns[list(np.arange(0,len(df.columns)))]),ignore_index=False)
    return new_df

# %%
def get_all_com(df_sub,scorer,list_of_mice):
    df_of_mice=pd.DataFrame(columns=['mouse','com_x','com_y'])
    for mouse in list_of_mice:
        good_flag, com_x, com_y=get_com(df_sub[df_sub.individuals==mouse])
        if good_flag > 0:
            df_of_mice=pd.concat([df_of_mice,pd.DataFrame(columns=df_of_mice.columns,data=[[mouse,com_x,com_y]])],axis=0)
    num_of_mice=len(np.unique(df_of_mice['mouse']))
    return df_of_mice, num_of_mice

# %%
def get_com(df):
    if sum(~np.isnan(list(df.value))) > 0:
        com_x=np.nanmedian(df[df.coords=='x'].value)
        com_y=np.nanmedian(df[df.coords=='y'].value)
        good_flag=1
    else:
        good_flag=0
        com_x=0
        com_y=0
    return good_flag, com_x,com_y

# %%
def closest(lst, n): 
    lst = np.asarray(lst)
    idx = (np.abs(lst - n)).argmin()
    return lst[idx], idx

# %%
def get_individual_for_frame(df,name,frame):
    df_i=df[df.scorer==name]
    df_i=df_i[df_i.level_2==frame]
    bp=np.unique(df_i.bodyparts)
    if len(bp) > 9:
        bp=np.unique(df_i.bodyparts)[[0,3,4,5,6,8,9,10,11]]
    return df_i, bp

# %%
def get_summary_from_mouse(ground_truth_subset,closest_match_subset):
    ptp=0
    pfp=0
    pfn=0
    body_parts=np.array(['body_center', 'left_ear', 'left_hip', 'left_side', 'nose', 'right_ear', 'right_hip', 'right_side', 'tail_base'], dtype=object)
    # for body_part in np.unique(bodyparts):
    bp_vals=[]
    for body_part in body_parts:
            print(body_part)
            lps_bp=ground_truth_subset[ground_truth_subset.bodyparts==body_part]
            ann_bp=closest_match_subset[closest_match_subset.bodyparts==body_part]
            ds=math.dist([list(lps_bp[lps_bp.coords=='x'].value)[0],list(ann_bp[ann_bp.coords=='y'].value)[0]],[list(ann_bp[ann_bp.coords=='x'].value)[0],list(lps_bp[lps_bp.coords=='y'].value)[0]])
            print('ds is {}'.format(ds))
            this_mouse_dists=[]
            # if no one annotated this part, skip, else
            if np.isnan(list(lps_bp[lps_bp.coords=='x'].value)[0])==False:
                # if LPS annotated
                # but annotator didn't, mark as false negative
                if np.isnan(list(ann_bp[ann_bp.coords=='x'].value)[0]):
                    pfn+=1
                # if LPS annotated and annotator did, mark as true positive and get dist
                else: 
                    ptp+=1
                    this_mouse_dists.append(ds)
            elif not np.isnan(list(ann_bp[ann_bp.coords=='x'].value)[0]):
                pfp+=1
                # if LPS didn't annotate but annotator did, mark as false positive
            # otherwise no one annotated, so skip this part
            bp_vals.append(np.nanmean(this_mouse_dists))
    bp_val=np.nanmean(bp_vals)
    return bp_val, pfp, pfn, ptp

# %% [markdown]
# # Use case

# %% [markdown]
# # Procedure

# %%
# load data
dates = ["0529_24B_27-20220114T211328Z-001\\0529_24B_27","0529_25B_23"]
base=str("C:\\Users\\dennise\\Downloads")
file_names=['CollectedData_nishan.csv','CollectedData_ejd.csv','CollectedData_LPS.csv','CollectedData_Jessica.csv']

list_of_mice=['mouse1','mouse2','mouse3','mouse4','mouse5','mouse6']
names=['LPS','nishan','Jessica','ejd']
ground_truth_scorer='LPS'
body_parts=np.array(['body_center', 'left_ear', 'left_hip', 'left_side', 'nose',
       'right_ear', 'right_hip', 'right_side', 'tail_base'], dtype=object)


# get data from each date
date=dates[0]
print(date)
df=load_and_reformat(os.path.join(base,date,file_names[0]))
print(file_names[0])
for name in file_names[1:]:
    print(file_names)
    df=pd.concat([df,load_and_reformat(os.path.join(base,date,name))],axis=0)
df=df.reset_index()
df.head()


date=dates[1]
print(date)
df2=load_and_reformat(os.path.join(base,date,file_names[0]))
for name in file_names[1:]:
    df2=pd.concat([df2,load_and_reformat(os.path.join(base,date,name))],axis=0)
df2=df2.reset_index()
# Out:
# 0529_24B_27-20220114T211328Z-001\0529_24B_27
# CollectedData_nishan.csv
# ['CollectedData_nishan.csv', 'CollectedData_ejd.csv', 'CollectedData_LPS.csv', 'CollectedData_Jessica.csv']
# ['CollectedData_nishan.csv', 'CollectedData_ejd.csv', 'CollectedData_LPS.csv', 'CollectedData_Jessica.csv']
# ['CollectedData_nishan.csv', 'CollectedData_ejd.csv', 'CollectedData_LPS.csv', 'CollectedData_Jessica.csv']
# 0529_25B_23

# %%
# make an empty df to store results
df_agg=pd.DataFrame(columns=['frame','scorer','total_mice','tp','fp','ptp','pfp','pfn','px'])

# for each frame
n=-1
for frame in np.unique(df.level_2):
    n+=1
    print('on frame {}, {} of {}'.format(frame,n,len(np.unique(df.level_2))))
    # get ground truth, in this case LPS data
    df_sub=df[df.level_2==frame]
    for scorer in names:
        print(scorer)
        df_sub_scorer=df_sub[df_sub.scorer==scorer]
        df_sub_com, l=get_all_com(df_sub_scorer,scorer,list_of_mice)
        df_sub_com=df_sub_com.reset_index()
        if scorer==ground_truth_scorer:
            ground_truth=df_sub_scorer
            ground_com, num_of_mice = get_all_com(ground_truth,ground_truth_scorer,list_of_mice)
            ground_com=ground_com.reset_index()
        else:
            # compare # of mice
            distance=10000000
            # get the closest mouse
            for idx in ground_com.index:
                print('idx is {}'.format(idx))
                for i in df_sub_com.index:
                    print('i is {}'.format(i))
                    new_dist=math.dist([df_sub_com.com_x[i],df_sub_com.com_y[i]],[ground_com.com_x[0],ground_com.com_y[0]])
                    if new_dist < distance:
                        distance=new_dist
                        good_i=i
                print('best match for {} is {}'.format(idx,good_i))
                ground_coords=ground_truth[ground_truth.individuals==ground_com.mouse[idx]]
                # use good_i to get the closest mouse
                closest_coords=df_sub_scorer[df_sub_scorer.individuals==df_sub_com.mouse[good_i]]
                # get data for these
                px, pfp, pfn, ptp = get_summary_from_mouse(ground_coords,closest_coords)
            
            if num_of_mice < l:
                print('LPS annotated fewer mice')
                tp=num_of_mice
                fp=l-num_of_mice      
            elif num_of_mice > l:
                print('LPS annotated more mice')
                tp=l
                fp=0
            else:
                tp=l
                fp=0
                print('both annotated same # of mice')
            
            # for each scorer, save frame data to df_agg
            df_agg=pd.concat([df_agg,pd.DataFrame(columns=['frame','scorer','total_mice','tp','fp','ptp','pfp','pfn','px'],data=[[frame,scorer,num_of_mice,tp,fp,ptp,pfp,pfn,px]])])
# Out:
# on frame img000.png, 0 of 9
# LPS
# nishan
# idx is 0
# i is 0
# best match for 0 is 0
# body_center
# ds is 1.701921786232093
# left_ear
# ds is 2.5761591831918067
# left_hip
# ds is 4.325544660414647
# left_side
# ds is 1.5876355210895736
# nose
# ds is 1.4148693443709652
# right_ear
# ds is 2.439748863451734
# right_hip
# ds is 2.350318161113047
# right_side
# ds is 2.824557946384717
# tail_base
# ds is nan
# both annotated same # of mice
# Jessica
# idx is 0
# i is 0
# best match for 0 is 0
# body_center
# ds is 2.3468300730991727
# left_ear
# ds is 1.860711042391747
# left_hip
# ds is nan
# left_side
# ds is 5.115127677912072
# nose
# ds is nan
# right_ear
# ds is 2.3668436110798905
# right_hip
# ds is nan
# right_side
# ds is 4.2163058626944
# tail_base
# ds is nan
# both annotated same # of mice
# ejd
# idx is 0
# i is 0
# best match for 0 is 0
# body_center
# ds is 6.429943523581705
# left_ear
# ds is 1.3172600133942907
# left_hip
# ds is nan
# left_side
# ds is 3.4717492286388385
# nose
# ds is 0.92737717853939
# right_ear
# ds is 2.9749522124112366
# right_hip
# ds is nan
# right_side
# ds is 1.722550846327829
# tail_base
# ds is nan
# both annotated same # of mice
# on frame img072.png, 1 of 9
# C:\Users\dennise\AppData\Local\Temp/ipykernel_20212/1312708997.py:29: RuntimeWarning: Mean of empty slice
#   bp_vals.append(np.nanmean(this_mouse_dists))
# LPS
# nishan
# idx is 0
# i is 0
# best match for 0 is 0
# body_center
# ds is 0.9716965967832056
# left_ear
# ds is 1.7913033244438978
# left_hip
# ds is 2.953540508045728
# left_side
# ds is nan
# nose
# ds is nan
# right_ear
# ds is 1.0030480365295609
# right_hip
# ds is 3.177907963097699
# right_side
# ds is nan
# tail_base
# ds is nan
# both annotated same # of mice
# Jessica
# idx is 0
# i is 0
# best match for 0 is 0
# body_center
# ds is 3.334664904521771
# left_ear
# ds is 1.1786772204345475
# left_hip
# ds is nan
# left_side
# ds is nan
# nose
# ds is nan
# right_ear
# ds is 3.556345210213021
# right_hip
# ds is 8.206778963671173
# right_side
# ds is nan
# tail_base
# ds is nan
# both annotated same # of mice
# ejd
# idx is 0
# i is 0
# best match for 0 is 0
# body_center
# ds is 4.4955807542027975
# left_ear
# ds is 3.126352621439515
# left_hip
# ds is 2.091723096809451
# left_side
# ds is 5.249847864437201
# nose
# ds is nan
# right_ear
# ds is 1.4313439786806859
# right_hip
# ds is 2.161480181307558
# right_side
# ds is 5.133852859595068
# tail_base
# ds is nan
# both annotated same # of mice
# on frame img125.png, 2 of 9
# LPS
# nishan
# idx is 0
# i is 0
# best match for 0 is 0
# body_center
# ds is 7.710917830722644
# left_ear
# ds is nan
# left_hip
# ds is 9.08649870148763
# left_side
# ds is nan
# nose
# ds is nan
# right_ear
# ds is 2.873474075581116
# right_hip
# ds is 6.597830666372917
# right_side
# ds is 2.183471775034607
# tail_base
# ds is 3.2793808728435807
# both annotated same # of mice
# Jessica
# idx is 0
# i is 0
# best match for 0 is 0
# body_center
# ds is 3.6538722572107334
# left_ear
# ds is nan
# left_hip
# ds is nan
# left_side
# ds is nan
# nose
# ds is nan
# right_ear
# ds is nan
# right_hip
# ds is 8.401553599329889
# right_side
# ds is 3.9716497101183768
# tail_base
# ds is 2.822238757864843
# both annotated same # of mice
# ejd
# idx is 0
# i is 0
# best match for 0 is 0
# body_center
# ds is 7.361324859510128
# left_ear
# ds is nan
# left_hip
# ds is nan
# left_side
# ds is 5.310368736160421
# nose
# ds is nan
# right_ear
# ds is 2.76670613423359
# right_hip
# ds is 8.684972835851944
# right_side
# ds is 3.8257236863647224
# tail_base
# ds is 1.9219932286374322
# both annotated same # of mice
# on frame img152.png, 3 of 9
# LPS
# nishan
# idx is 0
# i is 0
# best match for 0 is 0
# body_center
# ds is nan
# left_ear
# ds is nan
# left_hip
# ds is nan
# left_side
# ds is nan
# nose
# ds is nan
# right_ear
# ds is nan
# right_hip
# ds is 7.754144738321763
# right_side
# ds is nan
# tail_base
# ds is 3.133844061197151
# both annotated same # of mice
# Jessica
# idx is 0
# i is 0
# i is 1
# best match for 0 is 0
# body_center
# ds is nan
# left_ear
# ds is nan
# left_hip
# ds is nan
# left_side
# ds is nan
# nose
# ds is nan
# right_ear
# ds is nan
# right_hip
# ds is nan
# right_side
# ds is nan
# tail_base
# ds is 2.6865947759427034
# LPS annotated fewer mice
# ejd
# idx is 0
# i is 0
# best match for 0 is 0
# body_center
# ds is 5.2306246098769735
# left_ear
# ds is nan
# left_hip
# ds is 1.7152361486073653
# left_side
# ds is nan
# nose
# ds is nan
# right_ear
# ds is nan
# right_hip
# ds is 4.001099052751756
# right_side
# ds is nan
# tail_base
# ds is 4.683068012201303
# both annotated same # of mice
# on frame img312.png, 4 of 9
# LPS
# nishan
# idx is 0
# i is 0
# best match for 0 is 0
# body_center
# ds is 5.21530397265701
# left_ear
# ds is 4.255492472533006
# left_hip
# ds is nan
# left_side
# ds is 10.5360749515217
# nose
# ds is 2.569669513858086
# right_ear
# ds is 5.152592472028379
# right_hip
# ds is 4.732928501668616
# right_side
# ds is 4.873742578601602
# tail_base
# ds is 10.948818810949646
# both annotated same # of mice
# Jessica
# idx is 0
# i is 0
# best match for 0 is 0
# body_center
# ds is 4.923206814371339
# left_ear
# ds is nan
# left_hip
# ds is nan
# left_side
# ds is 8.181833365172661
# nose
# ds is 1.4053305511611671
# right_ear
# ds is 3.1558448868561686
# right_hip
# ds is 6.022816804984951
# right_side
# ds is 4.563484243744877
# tail_base
# ds is 9.835944013765651
# both annotated same # of mice
# ejd
# idx is 0
# i is 0
# best match for 0 is 0
# body_center
# ds is 6.5255925680022635
# left_ear
# ds is 3.347307731307604
# left_hip
# ds is 9.020669767753512
# left_side
# ds is 10.285529198207604
# nose
# ds is 0.9026951736963168
# right_ear
# ds is 3.8557653814917905
# right_hip
# ds is 7.121631217500734
# right_side
# ds is 3.843144138927069
# tail_base
# ds is 2.9786812037218535
# both annotated same # of mice
# on frame img445.png, 5 of 9
# LPS
# nishan
# idx is 0
# i is 0
# best match for 0 is 0
# body_center
# ds is 0.9529035243106972
# left_ear
# ds is 3.3896441601990577
# left_hip
# ds is 4.731055997587114
# left_side
# ds is 6.160557637232234
# nose
# ds is nan
# right_ear
# ds is 4.448071806534101
# right_hip
# ds is nan
# right_side
# ds is 6.088543781245483
# tail_base
# ds is nan
# both annotated same # of mice
# Jessica
# idx is 0
# i is 0
# best match for 0 is 0
# body_center
# ds is 2.043365521246158
# left_ear
# ds is 2.2481707815832044
# left_hip
# ds is 4.97517857368695
# left_side
# ds is 5.549779258638117
# nose
# ds is nan
# right_ear
# ds is 6.078303290135467
# right_hip
# ds is nan
# right_side
# ds is 4.079852142934304
# tail_base
# ds is nan
# both annotated same # of mice
# ejd
# idx is 0
# i is 0
# best match for 0 is 0
# body_center
# ds is 4.011747460286962
# left_ear
# ds is 4.542933436765907
# left_hip
# ds is 7.60977762426654
# left_side
# ds is 8.256557202449564
# nose
# ds is nan
# right_ear
# ds is 2.3724739030568553
# right_hip
# ds is nan
# right_side
# ds is 7.038902091302055
# tail_base
# ds is nan
# both annotated same # of mice
# on frame img547.png, 6 of 9
# LPS
# nishan
# idx is 0
# i is 0
# best match for 0 is 0
# body_center
# ds is 17.837223869699027
# left_ear
# ds is 2.844847218675708
# left_hip
# ds is nan
# left_side
# ds is 9.423287526299026
# nose
# ds is nan
# right_ear
# ds is nan
# right_hip
# ds is nan
# right_side
# ds is nan
# tail_base
# ds is 1.9207297174039248
# both annotated same # of mice
# Jessica
# idx is 0
# i is 0
# best match for 0 is 0
# body_center
# ds is 25.383348673666124
# left_ear
# ds is 1.807910575279908
# left_hip
# ds is nan
# left_side
# ds is 14.173549373143237
# nose
# ds is nan
# right_ear
# ds is 9.92593153243035
# right_hip
# ds is nan
# right_side
# ds is 18.686216540769966
# tail_base
# ds is 2.8519513873865576
# both annotated same # of mice
# ejd
# idx is 0
# i is 0
# best match for 0 is 0
# body_center
# ds is 13.59760847248749
# left_ear
# ds is 4.380493806046234
# left_hip
# ds is nan
# left_side
# ds is 8.024871203623315
# nose
# ds is nan
# right_ear
# ds is nan
# right_hip
# ds is nan
# right_side
# ds is 22.085170065998614
# tail_base
# ds is 1.5205203023582854
# both annotated same # of mice
# on frame img662.png, 7 of 9
# LPS
# nishan
# idx is 0
# i is 0
# best match for 0 is 0
# body_center
# ds is 8.935308965718669
# left_ear
# ds is 3.722738681519895
# left_hip
# ds is 9.069275089012287
# left_side
# ds is 5.6672990516121775
# nose
# ds is 4.139565107432338
# right_ear
# ds is 8.281427781997108
# right_hip
# ds is nan
# right_side
# ds is 9.05128118713451
# tail_base
# ds is nan
# both annotated same # of mice
# Jessica
# idx is 0
# i is 0
# best match for 0 is 0
# body_center
# ds is 1.4016404160303926
# left_ear
# ds is 2.223765444203062
# left_hip
# ds is nan
# left_side
# ds is 3.0210375177563993
# nose
# ds is 3.6700382481336886
# right_ear
# ds is 6.763046580988766
# right_hip
# ds is nan
# right_side
# ds is 2.4016518777510227
# tail_base
# ds is nan
# both annotated same # of mice
# ejd
# idx is 0
# i is 0
# best match for 0 is 0
# body_center
# ds is 8.78620590774841
# left_ear
# ds is 2.051623048234335
# left_hip
# ds is nan
# left_side
# ds is 4.690243953314593
# nose
# ds is 2.068967973764714
# right_ear
# ds is 7.076435093307761
# right_hip
# ds is nan
# right_side
# ds is 4.83231445211992
# tail_base
# ds is nan
# both annotated same # of mice
# on frame img899.png, 8 of 9
# LPS
# nishan
# both annotated same # of mice
# Jessica
# both annotated same # of mice
# ejd
# both annotated same # of mice

# %%
np.mean(df_agg[df_agg.scorer=='nishan'].px)
# Out:
# 5.038947790092253

# %%
np.mean(df_agg[df_agg.scorer=='Jessica'].px)
# Out:
# 4.950611142352708

# %%
np.mean(df_agg[df_agg.scorer=='ejd'].px)
# Out:
# 5.08816445806895
